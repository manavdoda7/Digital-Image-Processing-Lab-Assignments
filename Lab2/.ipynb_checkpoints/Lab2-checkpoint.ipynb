# %% [markdown]
# # Lab 2

# %% [markdown]
# ### Submitted By: Manav Doda
# ### Roll No.: 195057

# %% [markdown]
# ## Importing Necessary Modules

# %%
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# ## Objective 1

# %% [markdown]
# ### To understand and implement the following task in MATLAB:
# #### A: Image Addition

# %%
img1 = cv2.imread('chessboard.png', cv2.COLOR_BGR2GRAY)
img2 = cv2.imread('chessboardMirror.png', cv2.COLOR_BGR2GRAY)
print('Image 1')
plt.imshow(img1)
plt.show()
print('Image 2')
plt.imshow(img2)
plt.show()
# Out:
# Image 1
# Image 2

# %%
resAdd = cv2.imread('chessboard.png', cv2.COLOR_BGR2GRAY)
for i in range(img1.shape[0]):
    for j in range(img1.shape[1]):
        resAdd[i][j] = img1[i][j]+img2[i][j]
cv2.imwrite('resAdd.png', resAdd)
print('Image after conversion')
plt.imshow(resAdd)
plt.show()
# Out:
# Image after conversion

# %% [markdown]
# #### B: Image Negation

# %%
img = cv2.imread('testImage.jpeg')
print('Original Image')
plt.imshow(img)
plt.show()
print('Negative Image')
negativeImg= 255-img
plt.imshow(negativeImg)
plt.show()
cv2.imwrite('negativeTestImage.jpeg', negativeImg)
# Out:
# Original Image
# Negative Image
# True

# %% [markdown]
# ## Objective 2

# %% [markdown]
# #### Logical operations such as
# #### ‘NOT’ operation

# %%
img = cv2.imread('chessboard.png')
print('Original Image')
plt.imshow(img)
plt.show()
print('Image after applying NOT Operation')
notImg= 255-img
plt.imshow(notImg)
plt.show()
cv2.imwrite('resultNot.png', notImg)
# Out:
# Original Image
# Image after applying NOT Operation
# True

# %% [markdown]
# #### ‘OR’ Operation

# %%
img1=cv2.imread('chessboard.png', cv2.COLOR_BGR2GRAY)
img2=cv2.imread('chessboardMirror.png', cv2.COLOR_BGR2GRAY)
for i in range(img1.shape[0]):
    for j in range(img2.shape[0]):
        img1[i][j][0]=img1[i][j][0] | img2[i][j][0]
        img1[i][j][1]=img1[i][j][1] | img2[i][j][1]
        img1[i][j][2]=img1[i][j][2] | img2[i][j][2]
plt.imshow(img1)
plt.show()

# %% [markdown]
# #### ‘AND’ Operation

# %%
img1=cv2.imread('chessboard.png', cv2.COLOR_BGR2GRAY)
img2=cv2.imread('chessboardMirror.png', cv2.COLOR_BGR2GRAY)
for i in range(img1.shape[0]):
    for j in range(img2.shape[0]):
        img1[i][j][0]=img1[i][j][0] & img2[i][j][0]
        img1[i][j][1]=img1[i][j][1] & img2[i][j][1]
        img1[i][j][2]=img1[i][j][2] & img2[i][j][2]
plt.imshow(img1)
plt.show()

# %% [markdown]
# #### ‘XOR’ operation.

# %%
img1=cv2.imread('chessboard.png', cv2.COLOR_BGR2GRAY)
img2=cv2.imread('chessboardMirror.png', cv2.COLOR_BGR2GRAY)
for i in range(img1.shape[0]):
    for j in range(img2.shape[0]):
        img1[i][j][0]=img1[i][j][0] ^ img2[i][j][0]
        img1[i][j][1]=img1[i][j][1] ^ img2[i][j][1]
        img1[i][j][2]=img1[i][j][2] ^ img2[i][j][2]
plt.imshow(img1)
plt.show()
